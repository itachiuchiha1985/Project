# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Brain Tumor.csv', 'cancer patient data sets.csv', 'cancer patients.ipynb', 'cleaned cancer data.ipynb']

# %%
df = pd.read_csv("cancer patient data sets.csv")

# %%
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Patient Id                1000 non-null   object
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   int64
#  3   Air Pollution             1000 non-null   int64
#  4   Alcohol use               1000 non-null   int64
#  5   Dust Allergy              1000 non-null   int64
#  6   OccuPational Hazards      1000 non-null   int64
#  7   Genetic Risk              1000 non-null   int64
#  8   chronic Lung Disease      1000 non-null   int64
#  9   Balanced Diet             1000 non-null   int64
#  10  Obesity                   1000 non-null   int64
#  11  Smoking                   1000 non-null   int64
#  12  Passive Smoker            1000 non-null   int64
#  13  Chest Pain                1000 non-null   int64
# ...

# %%
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
df.isnull().sum()
# Out:
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Patient Id                  False
# Age                         False
# Gender                      False
# Air Pollution               False
# Alcohol use                 False
# Dust Allergy                False
# OccuPational Hazards        False
# Genetic Risk                False
# chronic Lung Disease        False
# Balanced Diet               False
# Obesity                     False
# Smoking                     False
# Passive Smoker              False
# Chest Pain                  False
# Coughing of Blood           False
# Fatigue                     False
# Weight Loss                 False
# Shortness of Breath         False
# Wheezing                    False
# Swallowing Difficulty       False
# Clubbing of Finger Nails    False
# Frequent Cold               False
# Dry Cough                   False
# Snoring                     False
# Level                       False
# dtype: bool

# %%
sns.heatmap(df.isnull(), yticklabels=False)
# Out:
# <Axes: >

# %%
sns.heatmap(df.isnull(), yticklabels=False, annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
df.dropna(how='all')
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
# import all the tools we need

# regular exploratory data analysis and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# we want our plots to appear inside the notebook
# %matplotlib inline 

# Models from Scikit-Learn
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# Model Evaluations
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, roc_auc_score

# %%
df = pd.read_csv("cancer patient data sets.csv")
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
df.shape
# Out:
# (1000, 25)

# %%
df.head(10)
# Out:
#   Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
# 5       P102   35       1              4            5             6
# 6       P103   52       2              2            4             5
# 7       P104   28       2              3            1             4
# 8       P105   35       2              4            5             6
# 9       P106   46       1              2            3             4
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# ...

# %%
df.tail(10)
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 990       P990   49       1              6            5             6
# 991       P991   37       1              8            8             7
# 992       P992   26       2              7            7             7
# 993       P993   37       2              7            7             7
# 994       P994   33       1              6            7             7
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 990                     5             5                     4              6
# ...

# %%
df["Level"].value_counts()
# Out:
# Level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %%
df["Level"].value_counts().plot(kind="bar", color=["red", "lightblue", "green"]);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Patient Id                1000 non-null   object
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   int64
#  3   Air Pollution             1000 non-null   int64
#  4   Alcohol use               1000 non-null   int64
#  5   Dust Allergy              1000 non-null   int64
#  6   OccuPational Hazards      1000 non-null   int64
#  7   Genetic Risk              1000 non-null   int64
#  8   chronic Lung Disease      1000 non-null   int64
#  9   Balanced Diet             1000 non-null   int64
#  10  Obesity                   1000 non-null   int64
#  11  Smoking                   1000 non-null   int64
#  12  Passive Smoker            1000 non-null   int64
#  13  Chest Pain                1000 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age       Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  1000.000000  1000.000000      1000.0000  1000.000000   1000.000000
# mean     37.174000     1.402000         3.8400     4.563000      5.165000
# std      12.005493     0.490547         2.0304     2.620477      1.980833
# min      14.000000     1.000000         1.0000     1.000000      1.000000
# 25%      27.750000     1.000000         2.0000     2.000000      4.000000
# 50%      36.000000     1.000000         3.0000     5.000000      6.000000
# 75%      45.000000     2.000000         6.0000     7.000000      7.000000
# max      73.000000     2.000000         8.0000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count           1000.000000   1000.000000           1000.000000
# mean               4.840000      4.580000              4.380000
# std                2.107805      2.126999              1.848518
# ...

# %%
df.Gender.value_counts()
# Out:
# Gender
# 1    598
# 2    402
# Name: count, dtype: int64

# %%
pd.crosstab(df.Level, df.Gender)
# Out:
# Gender    1    2
# Level
# High    252  113
# Low     149  154
# Medium  197  135

# %%
pd.crosstab(df.Level, df.Gender).plot(kind="bar",
                                      figsize=(10, 6),
                                      color=["red", "lightblue", "green"])
plt.title("cancer frequency for Gender")
plt.xlabel("High = Cancer, Low = No cancer, Medium = Most Likely Cancer")
plt.ylabel("Amount")
plt.legend(["Male", "Female"]);

# %%
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
df["Wheezing"].value_counts()
# Out:
# Wheezing
# 2    240
# 5    171
# 4    163
# 1    149
# 7    139
# 6     68
# 3     60
# 8     10
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df.Age[df.Level=="High"],
            df.Wheezing[df.Level=="High"],
            c="lightblue")
plt.xlabel("Age")
plt.ylabel("Maximum Wheezing for High Chance of Cancer")
plt.figure(figsize=(10, 6))
plt.scatter(df.Age[df.Level=="Low"],
            df.Wheezing[df.Level=="Low"],
            c="green");
plt.xlabel("Age")
plt.ylabel("Maximum Wheezing for Low Chance of Cancer")
# Out:
# Text(0, 0.5, 'Maximum Wheezing for Low Chance of Cancer')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df.Age[df.Level=="High"],
            df.Wheezing[df.Level=="High"],
            c="lightblue")
plt.scatter(df.Age[df.Level=="Low"],
            df.Wheezing[df.Level=="Low"],
            c="green")
plt.title("Cancer as a function of Age and Wheezing of High and Low Chance of cancer rate")
plt.xlabel("Age")
plt.ylabel("Maximum Wheezing for High and Low Chance of Cancer")
plt.legend(["Cancer", "No Cancer"]);

# %%
df.Age.plot.hist();

# %%
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %% [markdown]
# # Cancer Rate frequency per Dry Cough

# %%
pd.crosstab(df['Dry Cough'], df.Level)
# Out:
# Level      High  Low  Medium
# Dry Cough
# 1            39   60      20
# 2            60   70     121
# 3            30   71       0
# 4             0   61      80
# 5            50   20      61
# 6            58   21      10
# 7           128    0      40

# %%
pd.crosstab(df['Dry Cough'], df.Level).plot(kind="bar",
                                            figsize=(10, 6),
                                            color=["pink", "black", "yellow"])
plt.title("Cancer rate frequency per Dry Cough")
plt.xlabel("Dry Cough")
plt.ylabel("Amount")
plt.legend(["Cancer", "No Cancer", "Most Likely Cancer"])

# %% [markdown]
# # Modelling

# %%
df.head()
# Out:
#   Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %%
df['Levels'] =  df['Level']

# %%
df['Levels'].replace(['High'], 3, inplace=True)
df['Levels'].replace(['Medium'], 2, inplace=True)
df['Levels'].replace(['Low'], 1, inplace=True)
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
df = df.drop("Patient Id", axis=1)

# %%
df
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
df = df.drop("Level", axis=1)

# %%
df
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
x = df.drop("Levels", axis=1)
y = df["Levels"]

# %%
x
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
y
# Out:
# 0      1
# 1      2
# 2      3
# 3      3
# 4      3
#       ..
# 995    3
# 996    3
# 997    3
# 998    3
# 999    3
# Name: Levels, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
x_train
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 188   48       2              1            6             7
# 194   36       2              2            1             5
# 225   26       2              8            8             7
# 580   65       1              6            8             7
# 428   36       1              6            7             7
# ..   ...     ...            ...          ...           ...
# 320   19       1              6            8             7
# 527   36       2              2            1             5
# 996   37       2              6            8             7
# 125   27       2              3            1             4
# 265   17       2              1            2             3
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 188                     8             7                     6              7
# 194                     3             2                     3              2
# ...

# %%
y_train, len(y_train)
# Out:
# (188    2
#  194    2
#  225    3
#  580    2
#  428    3
#        ..
#  320    3
#  527    2
#  996    3
#  125    1
#  265    1
#  Name: Levels, Length: 800, dtype: int64,
#  800)

# %% [markdown]
# # Building a model

# %% [markdown]
# # Train the machine on the training set data
# # We'll test it on the test set
# # The 3 different machine learning model will be tried
# 1. Logistic Regression
# 2. K-Nearest Neighbours Classification
# 3. Random Forest Classifier

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([2.04885256, 2.85451939, 2.88026814, 0.82220834, 2.78306474,
#        1.87227465, 2.9608091 , 1.79159661, 3.15625022, 2.06305962,
#        2.79287717, 1.95164915, 1.8856279 , 0.9632952 , 1.02258204,
#        2.0439711 , 2.90717152, 1.89092836, 3.36279009, 1.25933838,
#        2.63026291, 1.18812774, 3.24361748, 2.95590457, 2.80874199,
#        1.76502575, 1.79159661, 1.01354768, 0.89156261, 1.76502575,
#        0.61954121, 1.91611443, 2.95590457, 1.18812774, 1.76267575,
#        3.36769461, 1.95727331, 2.9804366 , 1.77003253, 1.07130403,
#        1.76502575, 1.97683484, 3.12314469, 2.01076754, 2.9608091 ,
#        2.79287717, 1.41494993, 3.36279009, 2.97493798, 1.79055449,
#        1.8989486 , 1.94306624, 1.88653176, 2.79648068, 1.79055449,
#        2.51681567, 2.85362619, 2.69935217, 1.01756406, 2.80268283,
#        2.63026291, 1.13225037, 2.88026814, 1.23300037, 3.12314469,
#        0.61954121, 1.96023207, 2.97493798, 3.24361748, 2.06111386,
# ...

# %%
y_test
# Out:
# 841    2
# 956    3
# 544    3
# 173    1
# 759    3
#       ..
# 274    1
# 192    2
# 398    2
# 450    1
# 520    2
# Name: Levels, Length: 200, dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 0.9264604832083148

# %% [markdown]
# # Using KNN classifier

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
df.head(1000)
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0     33       1              2            4             5
# 1     17       1              3            1             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                       4             3                     2              2
# 1                       3             4                     2              2
# ...

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, 23].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        62
#            2       1.00      1.00      1.00        71
#            3       1.00      1.00      1.00        67
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
# [[62  0  0]
#  [ 0 71  0]
#  [ 0  0 67]]

# %% [markdown]
# # Using Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\DELL\Desktop\sampleproject\env\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test, y_test)
# Out:
# 0.995

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.98      1.00      0.99        62
#            2       1.00      0.99      0.99        71
#            3       1.00      1.00      1.00        67
#
#     accuracy                           0.99       200
#    macro avg       0.99      1.00      0.99       200
# weighted avg       1.00      0.99      1.00       200
#
# [[62  0  0]
#  [ 1 70  0]
#  [ 0  0 67]]

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[62  0  0]
#  [ 1 70  0]
#  [ 0  0 67]]

# %% [markdown]
# # Hyperparameter tuning for KNN model

# %%
train_scores = []
test_scores = []
neighbors = range(1, 21)
knn = KNeighborsClassifier()
for i in neighbors:
    knn.set_params(n_neighbors=i)
    knn.fit(x_train, y_train)
    train_scores.append(knn.score(x_train, y_train))
    test_scores.append(knn.score(x_test, y_test))

# %%
train_scores
# Out:
# [1.0,
#  1.0,
#  1.0,
#  1.0,
#  0.99875,
#  0.99875,
#  0.99875,
#  0.99875,
#  0.99875,
#  0.9975,
#  0.9975,
#  0.99,
#  0.99,
#  0.98125,
#  0.9825,
#  0.9825,
#  0.9525,
#  0.9525,
#  0.96125,
#  0.94875]

# %%
test_scores
# Out:
# [0.995,
#  0.995,
#  0.995,
#  0.995,
#  0.995,
#  0.995,
#  0.995,
#  0.995,
#  0.995,
#  0.995,
#  0.995,
#  0.98,
#  0.98,
#  0.965,
#  0.965,
#  0.965,
#  0.935,
#  0.94,
#  0.955,
#  0.955]

# %%
plt.plot(neighbors, train_scores, label="Train score")
plt.plot(neighbors, test_scores, label="Test score")
plt.xlabel("Number of neighbors")
plt.ylabel("Model score")
plt.legend()

print(f"Maximum KNN score on the test data: {max(test_scores)*100:.2f}%")
# Out:
# Maximum KNN score on the test data: 99.50%

# %% [markdown]
# # Hyperparameter tuning for logistic regression

# %%
from sklearn.datasets import make_blobs
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
x, y = make_blobs(n_samples=1000, centers=2, n_features=100, cluster_std=20)
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
penalty = ['12']
c_values = [100, 10, 1.0, 0.1, 0.01]
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy', error_score=0)
grid_results = grid_search.fit(x, y)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 13
#      11 cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
#      12 grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy', error_score=0)
# ---> 13 grid_results = grid_search.fit(x, y)
#      14 print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
#      15 means = grid_result.cv_results_['mean_test_score']
#
# File ~\Desktop\sampleproject\env\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# ...

# %% [markdown]
# # Hyperparameter tuning with RandomizedSearchCV(Logistic Regression)

# %%
log_reg_grid = {"C": np.logspace(-4, 4, 20),
                "solver": ["liblinear"]}

# %%
np.arange(10, 1000, 50)
# Out:
# array([ 10,  60, 110, 160, 210, 260, 310, 360, 410, 460, 510, 560, 610,
#        660, 710, 760, 810, 860, 910, 960])

# %%
np.random.seed(42)
rs_log_reg = RandomizedSearchCV(LogisticRegression(),
                                param_distributions=log_reg_grid,
                                cv=5,
                                n_iter=20,
                                verbose=True)
rs_log_reg.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(), n_iter=20,
#                    param_distributions={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                                         'solver': ['liblinear']},
#                    verbose=True)

# %%
rs_log_reg.best_params_
# Out:
# {'solver': 'liblinear', 'C': 29.763514416313132}

# %%
rs_log_reg.score(x_test, y_test)
# Out:
# 1.0

# %% [markdown]
# # Tuning using Grid search cv

# %%
log_reg_grid = {"C": np.logspace(-4, 4, 30),
                "solver": ["liblinear"]}
gs_log_reg = GridSearchCV(LogisticRegression(),
                          param_grid=log_reg_grid,
                          cv=5,
                          verbose=True)
gs_log_reg.fit(x_train, y_train);
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# C:\Users\DELL\Desktop\sampleproject\env\Lib\site-packages\sklearn\svm\_base.py:1242: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
gs_log_reg.best_params_
# Out:
# {'C': 32.90344562312671, 'solver': 'liblinear'}

# %%
 gs_log_reg.score(x_test, y_test)
# Out:
# 1.0
